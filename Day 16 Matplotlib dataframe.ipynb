# %%
print("Hello world !!!")
# Out:
# Hello world !!!

# %%
import numpy as np

import pandas as pd

from matplotlib import pyplot as plt

# %%
#reading a file:

df=pd.read_csv('countries.csv')

# %%
df
# Out:
#           country  year  population
# 0     Afghanistan  1952     8425333
# 1     Afghanistan  1957     9240934
# 2     Afghanistan  1962    10267083
# 3     Afghanistan  1967    11537966
# 4     Afghanistan  1972    13079460
# ...           ...   ...         ...
# 1699     Zimbabwe  1987     9216418
# 1700     Zimbabwe  1992    10704340
# 1701     Zimbabwe  1997    11404948
# 1702     Zimbabwe  2002    11926563
# 1703     Zimbabwe  2007    12311143
#
# [1704 rows x 3 columns]

# %%
uniquecount=df['country']

# %%
len(pd.unique(uniquecount))
# Out:
# 142

# %%
Compare the population of china and us:
========================================

# %%
us=df[df.country=='United States']

# %%
us
# Out:
#             country  year  population
# 1608  United States  1952   157553000
# 1609  United States  1957   171984000
# 1610  United States  1962   186538000
# 1611  United States  1967   198712000
# 1612  United States  1972   209896000
# 1613  United States  1977   220239000
# 1614  United States  1982   232187835
# 1615  United States  1987   242803533
# 1616  United States  1992   256894189
# 1617  United States  1997   272911760
# 1618  United States  2002   287675526
# 1619  United States  2007   301139947

# %%
china=df[df.country=='China']

# %%
china
# Out:
#     country  year  population
# 288   China  1952   556263527
# 289   China  1957   637408000
# 290   China  1962   665770000
# 291   China  1967   754550000
# 292   China  1972   862030000
# 293   China  1977   943455000
# 294   China  1982  1000281000
# 295   China  1987  1084035000
# 296   China  1992  1164970000
# 297   China  1997  1230075000
# 298   China  2002  1280400000
# 299   China  2007  1318683096

# %%
plt.plot(us.year,us.population)
plt.xlabel('years')

plt.ylabel('population')

plt.title("population in United states between years 1952 -2007")

plt.legend(['The curve represents the population change'])  # le8 ,on left top means it can have 8 numbers

plt.show()

# %%
plt.plot(china.year,china.population/10**6)  # here we are dividing the big number with 1 milion
plt.xlabel('years')

plt.ylabel('population')

plt.title("population in china between years 1952 -2007")

plt.legend(['The curve represents the population change'])  

plt.show()

# %%
Activity:
=========

# %%
Representation of the five countries data:
+============================================+

# %%
spa=df[df.country=='Spain']

spa
# Out:
#      country  year  population
# 1416   Spain  1952    28549870
# 1417   Spain  1957    29841614
# 1418   Spain  1962    31158061
# 1419   Spain  1967    32850275
# 1420   Spain  1972    34513161
# 1421   Spain  1977    36439000
# 1422   Spain  1982    37983310
# 1423   Spain  1987    38880702
# 1424   Spain  1992    39549438
# 1425   Spain  1997    39855442
# 1426   Spain  2002    40152517
# 1427   Spain  2007    40448191

# %%
data=pd.read_csv('countries.csv')

# %%
data[data.country=='South Africa']
# Out:
#            country  year  population
# 1404  South Africa  1952    14264935
# 1405  South Africa  1957    16151549
# 1406  South Africa  1962    18356657
# 1407  South Africa  1967    20997321
# 1408  South Africa  1972    23935810
# 1409  South Africa  1977    27129932
# 1410  South Africa  1982    31140029
# 1411  South Africa  1987    35933379
# 1412  South Africa  1992    39964159
# 1413  South Africa  1997    42835005
# 1414  South Africa  2002    44433622
# 1415  South Africa  2007    43997828

# %%
pop_spain=data[data.country=='Spain']

pop_mx=data[data.country=='Mexico']

pop_ind=data[data.country=='India']



pop_sou=data[data.country=='South Africa']

pop_net=data[data.country=='Netherlands']


plt.plot(pop_spain.year,pop_spain.population/10**6)

plt.plot(pop_mx.year,pop_mx.population/10**6)

plt.plot(pop_ind.year,pop_ind.population/10**6)

plt.plot(pop_sou.year,pop_sou.population/10**6)

plt.plot(pop_net.year,pop_net.population/10**6)


plt.xlabel('years')

plt.ylabel('population')

plt.title("population in between years 1952 -2007 of various countries")

plt.legend(['The curve represents the population change of spain',
            'The curve represents the population change of Mexico',
            'The curve represents the population change of India',
           'The curve represents the population change of south Africa',
           'The curve represents the population change of Netherlands'],loc="upper right")




plt.show()

# %%
spa=data[data.country=='Spain']    # country spain

# %%
spa
# Out:
#      country  year  population
# 1416   Spain  1952    28549870
# 1417   Spain  1957    29841614
# 1418   Spain  1962    31158061
# 1419   Spain  1967    32850275
# 1420   Spain  1972    34513161
# 1421   Spain  1977    36439000
# 1422   Spain  1982    37983310
# 1423   Spain  1987    38880702
# 1424   Spain  1992    39549438
# 1425   Spain  1997    39855442
# 1426   Spain  2002    40152517
# 1427   Spain  2007    40448191

# %%
plt.plot(spa.year,spa.population/10**6)

plt.xlabel('years')

plt.ylabel('population')

plt.title('population between the years  1952-2007')

plt.legend(['The curve of the spain'])

plt.show()

# %%
mex=data[data.country=='Mexico']

mex
# Out:
#     country  year  population
# 984  Mexico  1952    30144317
# 985  Mexico  1957    35015548
# 986  Mexico  1962    41121485
# 987  Mexico  1967    47995559
# 988  Mexico  1972    55984294
# 989  Mexico  1977    63759976
# 990  Mexico  1982    71640904
# 991  Mexico  1987    80122492
# 992  Mexico  1992    88111030
# 993  Mexico  1997    95895146
# 994  Mexico  2002   102479927
# 995  Mexico  2007   108700891

# %%
plt.plot(mex.year,mex.population/10**6,color='red')  # Mexico

plt.xlabel('years')

plt.ylabel('population')

plt.title('population between the years  1952-2007')

plt.legend(['The curve of the Mexico!!'])

plt.show()

# %%
ind=data[data.country=='India']

ind
# Out:
#     country  year  population
# 696   India  1952   372000000
# 697   India  1957   409000000
# 698   India  1962   454000000
# 699   India  1967   506000000
# 700   India  1972   567000000
# 701   India  1977   634000000
# 702   India  1982   708000000
# 703   India  1987   788000000
# 704   India  1992   872000000
# 705   India  1997   959000000
# 706   India  2002  1034172547
# 707   India  2007  1110396331

# %%
plt.plot(ind.year,ind.population/10**6,color='blue')  # India

plt.xlabel('years')

plt.ylabel('population')

plt.title('population between the years  1952-2007')

plt.legend(['The population curve of the India'])

plt.show()

# %%
sou=data[data.country=='South Africa']

sou
# Out:
#            country  year  population
# 1404  South Africa  1952    14264935
# 1405  South Africa  1957    16151549
# 1406  South Africa  1962    18356657
# 1407  South Africa  1967    20997321
# 1408  South Africa  1972    23935810
# 1409  South Africa  1977    27129932
# 1410  South Africa  1982    31140029
# 1411  South Africa  1987    35933379
# 1412  South Africa  1992    39964159
# 1413  South Africa  1997    42835005
# 1414  South Africa  2002    44433622
# 1415  South Africa  2007    43997828

# %%
plt.plot(sou.year,sou.population/10**6,color='green')  # South Afria

plt.xlabel('years')

plt.ylabel('population')

plt.title('population between the years  1952-2007')

plt.legend(['The population curve of the South Africa'])

plt.show()

# %%
net=data[data.country=='Netherlands']

net
# Out:
#           country  year  population
# 1080  Netherlands  1952    10381988
# 1081  Netherlands  1957    11026383
# 1082  Netherlands  1962    11805689
# 1083  Netherlands  1967    12596822
# 1084  Netherlands  1972    13329874
# 1085  Netherlands  1977    13852989
# 1086  Netherlands  1982    14310401
# 1087  Netherlands  1987    14665278
# 1088  Netherlands  1992    15174244
# 1089  Netherlands  1997    15604464
# 1090  Netherlands  2002    16122830
# 1091  Netherlands  2007    16570613

# %%
plt.plot(net.year,net.population/10**6,color='violet')  # South Afria

plt.xlabel('years')

plt.ylabel('population')

plt.title('population between the years  1952-2007')

plt.legend(['The population curve of the Netherlands'])

plt.show()
